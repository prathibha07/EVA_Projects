# %%
# !ls
# !rm -fr darknet
# !git clone https://github.com/AlexeyAB/darknet/
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 12467 (delta 8), reused 12 (delta 6), pack-reused 12449
# Receiving objects: 100% (12467/12467), 11.43 MiB | 14.60 MiB/s, done.
# Resolving deltas: 100% (8500/8500), done.

# %%
import os

# %%
# !ls
# Out:
# 3rdparty      cmake		      image_yolov2.sh	     net_cam_v3.sh
# appveyor.yml  CMakeLists.txt	      image_yolov3.sh	     README.md
# build	      DarknetConfig.cmake.in  include		     scripts
# build.ps1     darknet.py	      json_mjpeg_streams.sh  src
# build.sh      darknet_video.py	      LICENSE		     video_v2.sh
# cfg	      data		      Makefile		     video_yolov3.sh

# %%
#Now let's see whether the GPU is here and CUDA was successfully installed!
import tensorflow as tf
device_name = tf.test.gpu_device_name()
print(device_name)

print("helllooooo")

# !/usr/local/cuda/bin/nvcc --version
# Out:
# /device:GPU:0
# helllooooo
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130

# %%
# !ls
#import sys
#sys.path.insert(1, './Yolo-Training-GoogleColab/')
# Out:
# darknet  sample_data

# %%
# !unzip '/My Drive/Colab Notebooks/EVA/phase2/yolo/data_for_colab.zip'
# Out:
# unzip:  cannot find or open /gdrive/Colab Notebooks/EVA/phase2/yolo/data_for_colab.zip, /gdrive/Colab Notebooks/EVA/phase2/yolo/data_for_colab.zip.zip or /gdrive/Colab Notebooks/EVA/phase2/yolo/data_for_colab.zip.ZIP.

# %%
# !ls
import sys
#sys.path.insert(1, './Yolo-Training-GoogleColab/')
#sys.path.insert(1, '/content/gdrive/My Drive/Colab Notebooks/EVA/phase2/yolo/datasets/dog_darknet/data_for_colab/')
sys.path.insert(1, './datasets/dog_darknet/data_for_colab/')
# Out:
# 3rdparty      CMakeLists.txt	      include		     src
# appveyor.yml  DarknetConfig.cmake.in  json_mjpeg_streams.sh  video_v2.sh
# build	      darknet.py	      LICENSE		     video_yolov3.sh
# build.ps1     darknet_video.py	      Makefile		     yolov3.weights
# build.sh      data		      net_cam_v3.sh
# cfg	      image_yolov2.sh	      README.md
# cmake	      image_yolov3.sh	      scripts

# %%
# !ls
# Out:
# darknet  sample_data

# %%
# !apt-get install build-essential
# !apt-get install cmake git libgtk2.0-dev pkg-config libavcodec-dev libavformat-dev libswscale-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# pkg-config is already the newest version (0.29.1-0ubuntu2).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# git is already the newest version (1:2.17.1-1ubuntu0.5).
# libavcodec-dev is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# libavcodec-dev set to manually installed.
# libavformat-dev is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# libavformat-dev set to manually installed.
# libswscale-dev is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# ...

# %%
# !apt-get install libavcodec-dev libavformat-dev libswscale-d
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package libswscale-d

# %%
# !apt-get -y install cmake
# !which cmake

# !cmake --version
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.
# /usr/local/bin/cmake
# cmake version 3.12.0
#
# CMake suite maintained and supported by Kitware (kitware.com/cmake).

# %%
# !apt-get install libopencv-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libopencv-dev is already the newest version (3.2.0+dfsg-4ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.

# %%
# !apt-get install vim
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libgpm2 vim-common vim-runtime xxd
# Suggested packages:
#   gpm ctags vim-doc vim-scripts
# The following NEW packages will be installed:
#   libgpm2 vim vim-common vim-runtime xxd
# 0 upgraded, 5 newly installed, 0 to remove and 25 not upgraded.
# Need to get 6,721 kB of archives.
# After this operation, 32.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xxd amd64 2:8.0.1453-1ubuntu1.1 [49.2 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 vim-common all 2:8.0.1453-1ubuntu1.1 [70.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgpm2 amd64 1.20.7-5 [15.1 kB]
# ...

# %%
# !ls
# Out:
# darknet  sample_data

# %%
#Now let's get some YOLOv3 weights from the official site
# !ls
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# darknet  sample_data
# --2020-02-18 06:21:12--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  27.9MB/s    in 6.7s
#
# 2020-02-18 06:21:19 (35.4 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
#Now here we're modifying the makefile to set OPENCV and GPU to 1
# !ls
# !sed -i 's/OPENCV=0/OPENCV=1/g' ./darknet/Makefile
# !sed -i 's/GPU=0/GPU=1/g' ./darknet/Makefile
# Out:
# darknet  sample_data  yolov3.weights

# %%
# !ls
# %cd ../
# !ls
# Out:
# darknet  sample_data  yolov3.weights
# /
# bin					   etc	  opt	 sys
# boot					   home   proc	 tensorflow-2.1.0
# content					   lib	  root	 tmp
# datalab					   lib32  run	 tools
# dev					   lib64  sbin	 usr
# dlib-19.18.0-cp27-cp27mu-linux_x86_64.whl  media  srv	 var
# dlib-19.18.0-cp36-cp36m-linux_x86_64.whl   mnt	  swift

# %%
# !apt install g++-5
# !apt install gcc-5

# !update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-5 10
# !update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-5 20
# !update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-5 10
# !update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-5 20
# !update-alternatives --install /usr/bin/cc cc /usr/bin/gcc 30
# !update-alternatives --set cc /usr/bin/gcc
# !update-alternatives --install /usr/bin/c++ c++ /usr/bin/g++ 30
# !update-alternatives --set c++ /usr/bin/g++
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   cpp-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# Suggested packages:
#   gcc-5-locales g++-5-multilib gcc-5-doc libstdc++6-5-dbg gcc-5-multilib
#   libgcc1-dbg libgomp1-dbg libitm1-dbg libatomic1-dbg libasan2-dbg
#   liblsan0-dbg libtsan0-dbg libubsan0-dbg libcilkrts5-dbg libmpx0-dbg
#   libquadmath0-dbg libstdc++-5-doc
# The following NEW packages will be installed:
#   cpp-5 g++-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# 0 upgraded, 9 newly installed, 0 to remove and 25 not upgraded.
# Need to get 29.1 MB of archives.
# After this operation, 100 MB of additional disk space will be used.
# ...

# %%
#Now, here's a bunch of code that takes the longest to execute here but
#It's about installing CUDA and using the beautiful Tesla K80 GPU, so that
#Will worth it

# !apt update -qq;
# !wget https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# !dpkg -i cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# !apt-get update -qq

#Here were are installing compilers and creating some links
# !apt-get install cuda -y -qq #gcc-5 g++-5 
#!ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc
#!ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++
# !apt update
# !apt upgrade
# !apt install cuda-8.0 -y
# Out:
# 102 packages can be upgraded. Run 'apt list --upgradable' to see them.
# 102 packages can be upgraded. Run 'apt list --upgradable' to see them.
# --2020-02-18 06:24:26--  https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# Resolving developer.nvidia.com (developer.nvidia.com)... 192.229.162.216
# Connecting to developer.nvidia.com (developer.nvidia.com)|192.229.162.216|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/cuda/8.0/secure/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64.deb?LJRuOSSiQb-d1a4Z-HOZJHhJ7pctTnXaDl1X1Ln8AoEj4jDLW8_dVn7trYnx2Bl0gEw8PTUkyD6x9hJTEUwFbUkcEFnNDntipdJZ8gHaO4AUad4qY4OpmKJSVp4os7a1S27j-EHyXaKjVXPw8yYpvIiaE50L3FdUK0Hs_PfqH1YaLvn1tw8Kfk6b3Qhh4M0ilQIJM9-EtfTlkwEak2wKcfODZw [following]
# ...

# %%
#Now let's see whether the GPU is here and CUDA was successfully installed!
import tensorflow as tf
device_name = tf.test.gpu_device_name()
print(device_name)

print("Hellllooooo")

# !/usr/local/cuda/bin/nvcc --version
# Out:
# /device:GPU:0
# Hellllooooo
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2016 NVIDIA Corporation
# Built on Tue_Jan_10_13:22:03_CST_2017
# Cuda compilation tools, release 8.0, V8.0.61

# %%
ls
# Out:
# bin/                                                   mnt/
# boot/                                                  opt/
# content/                                               proc/
# cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb  root/
# datalab/                                               run/
# dev/                                                   sbin/
# dlib-19.18.0-cp27-cp27mu-linux_x86_64.whl              srv/
# dlib-19.18.0-cp36-cp36m-linux_x86_64.whl               swift/
# etc/                                                   sys/
# home/                                                  tensorflow-2.1.0/
# lib/                                                   tmp/
# lib32/                                                 tools/
# lib64/                                                 usr/
# media/                                                 var/

# %%
# %cd ../content
# Out:
# /content

# %%
# !ls
# Out:
# darknet  sample_data  yolov3.weights

# %%
# %cd darknet/
# Out:
# /content/darknet

# %%
# !ls
# !make
# Out:
# 3rdparty      CMakeLists.txt	      image_yolov3.sh	     scripts
# appveyor.yml  DarknetConfig.cmake.in  include		     src
# build	      darknet.py	      json_mjpeg_streams.sh  video_v2.sh
# build.ps1     darknet_video.py	      LICENSE		     video_yolov3.sh
# build.sh      data		      Makefile
# cfg	      data_for_colab.zip      net_cam_v3.sh
# cmake	      image_yolov2.sh	      README.md
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:909:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
# ...

# %%
# !ls #darknet parent folder
# Out:
# 3rdparty      CMakeLists.txt	      image_yolov3.sh	     results
# appveyor.yml  darknet		      include		     scripts
# backup	      DarknetConfig.cmake.in  json_mjpeg_streams.sh  src
# build	      darknet.py	      LICENSE		     video_v2.sh
# build.ps1     darknet_video.py	      Makefile		     video_yolov3.sh
# build.sh      data		      net_cam_v3.sh
# cfg	      data_for_colab.zip      obj
# cmake	      image_yolov2.sh	      README.md

# %%
import cv2

# %%
# !ls
#Now, let's see if everything works by running it on a test image
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/person.jpg
# Out:
# 3rdparty      CMakeLists.txt	      image_yolov3.sh	     results
# appveyor.yml  darknet		      include		     scripts
# backup	      DarknetConfig.cmake.in  json_mjpeg_streams.sh  src
# build	      darknet.py	      LICENSE		     video_v2.sh
# build.ps1     darknet_video.py	      Makefile		     video_yolov3.sh
# build.sh      data		      net_cam_v3.sh
# cfg	      data_for_colab.zip      obj
# cmake	      image_yolov2.sh	      README.md
#  CUDA-version: 8000 (10010), GPU count: 1
#  OpenCV version: 3.2.0
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
# ...

# %%
# !unzip data_for_colab.zip
# Out:
# Archive:  data_for_colab.zip
# replace data_for_colab/class.list.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#  extracting: data_for_colab/class.list.txt
# replace data_for_colab/data/1.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: data_for_colab/data/1.jpg
#  extracting: data_for_colab/data/1.txt
#   inflating: data_for_colab/data/10.jpg
#  extracting: data_for_colab/data/10.txt
#   inflating: data_for_colab/data/100.jpg
#  extracting: data_for_colab/data/100.txt
#   inflating: data_for_colab/data/101.jpg
#  extracting: data_for_colab/data/101.txt
#   inflating: data_for_colab/data/102.jpg
#  extracting: data_for_colab/data/102.txt
#   inflating: data_for_colab/data/103.jpg
#  extracting: data_for_colab/data/103.txt
#   inflating: data_for_colab/data/104.jpg
#  extracting: data_for_colab/data/104.txt
#   inflating: data_for_colab/data/105.jpg
#  extracting: data_for_colab/data/105.txt
#   inflating: data_for_colab/data/106.jpg
# ...

# %%
# !./darknet detect cfg/yolov3.cfg ../yolov3.weights data_for_colab/data/1.jpg
# Out:
#  CUDA-version: 8000 (10010), GPU count: 1
#  OpenCV version: 3.2.0
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
# ...

# %%
#Let's define some functions that will let us show images, and upload and 
#download files
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()
  
  
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)
def download(path):
  from google.colab import files
  files.download(path)

# %%
path= 'content/gdrive/My Drive/Colab Notebooks/EVA/phase2/yolo/datasets/dog_darknet/data_for_colab/data'

# %%
#Let's define some functions that will let us show images, and upload and 
#download files
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path,cv2.IMREAD_UNCHANGED)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)
  cv2_imshow(image)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()
  
  
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)
def download(path):
  from google.colab import files
  files.download(path)

# %%
imShow('content/gdrive/My Drive/Colab Notebooks/EVA/phase2/yolo/datasets/dog_darknet/data_for_colab/data/1.jpg')

# %%
# !ls
# Out:
# 3rdparty      cmake		      image_yolov2.sh	     predictions.jpg
# appveyor.yml  CMakeLists.txt	      image_yolov3.sh	     README.md
# backup	      darknet		      include		     results
# bad.list      DarknetConfig.cmake.in  json_mjpeg_streams.sh  scripts
# build	      darknet.py	      LICENSE		     src
# build.ps1     darknet_video.py	      Makefile		     video_v2.sh
# build.sh      data		      net_cam_v3.sh	     video_yolov3.sh
# cfg	      data_for_colab.zip      obj

# %%
# !mv ../Yolo-Training-GoogleColab/data_for_colab/ .

# %%
# !./darknet detector train data_for_colab/obj.data data_for_colab/yolov3-tiny-obj.cfg data_for_colab/yolov3-tiny.conv.15 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.678596, GIOU: 0.670329), Class: 0.995506, Obj: 0.327868, No Obj: 0.002484, .5R: 0.812500, .75R: 0.343750, count: 32, class_loss = 0.645438, iou_loss = 0.327543, total_loss = 0.972980
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000034, .5R: -nan, .75R: -nan, count: 0, class_loss = 0.000004, iou_loss = 0.000000, total_loss = 0.000004
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.657718, GIOU: 0.649876), Class: 0.992859, Obj: 0.296442, No Obj: 0.002203, .5R: 0.843750, .75R: 0.312500, count: 32, class_loss = 0.669615, iou_loss = 0.354076, total_loss = 1.023691
# ...

# %%
/content/darknet/data_for_colab/train.txt

# %%
ls
# Out:
# 3rdparty/                  darknet*                Makefile
# appveyor.yml               DarknetConfig.cmake.in  net_cam_v3.sh*
# backup/                    darknet.py              obj/
# bad.list                   darknet_video.py        predictions.jpg
# build/                     data/                   README.md
# build.ps1*                 data_for_colab/         results/
# build.sh*                  data_for_colab.zip      scripts/
# cfg/                       image_yolov2.sh*        src/
# chart.png                  image_yolov3.sh*        video_v2.sh*
# chart_yolov3-tiny-obj.png  include/                video_yolov3.sh*
# cmake/                     json_mjpeg_streams.sh*
# CMakeLists.txt             LICENSE

# %%
# !./darknet detector test data_for_colab/obj.data data_for_colab/yolov3-tiny-obj.cfg /darknet/data_for_colab/yolov3-tiny-obj_last.weights data_for_colab/data/108.jpg -i 0 -thresh 0.5
imShow('predictions.jpg')
#/content/darknet/data_for_colab/yolov3-tiny-obj_1000.weights
# Out:
#  CUDA-version: 8000 (10010), GPU count: 1
#  OpenCV version: 3.2.0
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
#    8 conv    256       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 256 0.399 BF
# ...

# %%
# detect on video /content/darknet/youtube_dog.mp4


# !./darknet detector demo data_for_colab/obj.data data_for_colab/yolov3-tiny-obj.cfg data_for_colab/yolov3-tiny-obj_1000.weights -dont_show -thresh 0.1 ../darknet/youtube_dog.mp4 -i 0 -out_filename veout.avi
# Out:
# Streaming output truncated to the last 5000 lines.
#
#  cvWriteFrame
# Objects:
#
#
# FPS:225.0 	 AVG_FPS:210.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:224.8 	 AVG_FPS:210.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:222.8 	 AVG_FPS:210.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:222.9 	 AVG_FPS:210.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:221.1 	 AVG_FPS:210.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:221.0 	 AVG_FPS:210.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:218.4 	 AVG_FPS:210.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:226.5 	 AVG_FPS:210.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:224.3 	 AVG_FPS:210.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:222.7 	 AVG_FPS:210.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:221.3 	 AVG_FPS:210.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:221.5 	 AVG_FPS:210.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:219.1 	 AVG_FPS:210.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:220.0 	 AVG_FPS:222.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:218.3 	 AVG_FPS:222.0
#
#  cvWriteFrame
# Objects:
#
# ...

# %%
# !./darknet detector demo data_for_colab/obj.data data_for_colab/yolov3-tiny-obj.cfg data_for_colab/yolov3-tiny-obj_1000.weights -dont_show -thresh 0.1 ../darknet/youtube_dog.mp4 -i 0 -out_filename veout1.mp4
# Out:
# Streaming output truncated to the last 5000 lines.
#
#  cvWriteFrame
# Objects:
#
#
# FPS:247.5 	 AVG_FPS:202.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:247.6 	 AVG_FPS:202.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:246.7 	 AVG_FPS:202.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:246.8 	 AVG_FPS:202.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:245.9 	 AVG_FPS:202.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:245.3 	 AVG_FPS:202.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:244.6 	 AVG_FPS:202.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:244.8 	 AVG_FPS:202.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:244.3 	 AVG_FPS:202.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:244.8 	 AVG_FPS:202.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:243.8 	 AVG_FPS:202.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:243.8 	 AVG_FPS:202.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:242.8 	 AVG_FPS:202.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:243.5 	 AVG_FPS:202.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:242.9 	 AVG_FPS:202.3
#
#  cvWriteFrame
# Objects:
#
# ...

# %%
# !./darknet detector demo data_for_colab/obj.data data_for_colab/yolov3-tiny-obj.cfg data_for_colab/yolov3-tiny-obj_1000.weights -dont_show -thresh 0.1 ../darknet/trailer_dog.mp4 -i 0 -out_filename veout_trailer.avi
# Out:
# Streaming output truncated to the last 5000 lines.
#
#  cvWriteFrame
# Objects:
#
# dog: 12%
#
# FPS:233.4 	 AVG_FPS:227.4
#
#  cvWriteFrame
# Objects:
#
# dog: 11%
#
# FPS:234.9 	 AVG_FPS:227.4
#
#  cvWriteFrame
# Objects:
#
# dog: 13%
#
# FPS:233.9 	 AVG_FPS:227.4
#
#  cvWriteFrame
# Objects:
#
# dog: 16%
#
# FPS:235.2 	 AVG_FPS:227.4
#
#  cvWriteFrame
# Objects:
#
# dog: 19%
#
# FPS:235.0 	 AVG_FPS:227.4
#
#  cvWriteFrame
# Objects:
#
# dog: 17%
#
# FPS:236.0 	 AVG_FPS:227.4
#
#  cvWriteFrame
# Objects:
#
# dog: 22%
#
# FPS:236.4 	 AVG_FPS:227.4
#
#  cvWriteFrame
# Objects:
#
# dog: 19%
#
# FPS:237.6 	 AVG_FPS:227.4
#
#  cvWriteFrame
# Objects:
#
# dog: 19%
#
# FPS:237.0 	 AVG_FPS:227.4
#
#  cvWriteFrame
# Objects:
#
# dog: 19%
#
# FPS:238.0 	 AVG_FPS:227.4
#
#  cvWriteFrame
# Objects:
#
# dog: 22%
#
# FPS:238.4 	 AVG_FPS:227.4
#
#  cvWriteFrame
# Objects:
#
# dog: 16%
#
# FPS:238.6 	 AVG_FPS:227.4
#
#  cvWriteFrame
# Objects:
#
# dog: 21%
#
# FPS:235.4 	 AVG_FPS:227.4
#
# ...

# %%
#art of rcing trailer 
# !./darknet detector demo data_for_colab/obj.data data_for_colab/yolov3-tiny-obj.cfg data_for_colab/yolov3-tiny-obj_1000.weights -dont_show -thresh 0.1 ../darknet/trailer_dog.mp4 -i 0 -out_filename veout2.avi
# Out:
# Streaming output truncated to the last 5000 lines.
#
# FPS:69.4 	 AVG_FPS:77.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:67.8 	 AVG_FPS:77.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:67.7 	 AVG_FPS:77.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:66.8 	 AVG_FPS:77.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:68.2 	 AVG_FPS:77.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:68.3 	 AVG_FPS:77.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:67.6 	 AVG_FPS:77.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:69.6 	 AVG_FPS:77.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:70.6 	 AVG_FPS:77.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:71.6 	 AVG_FPS:77.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:70.9 	 AVG_FPS:77.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:71.5 	 AVG_FPS:77.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:72.4 	 AVG_FPS:77.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:73.5 	 AVG_FPS:77.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:74.3 	 AVG_FPS:77.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:74.0 	 AVG_FPS:77.2
#
#  cvWriteFrame
# Objects:
#
#
# ...

# %%
#funny dog
# !./darknet detector demo data_for_colab/obj.data data_for_colab/yolov3-tiny-obj.cfg data_for_colab/yolov3-tiny-obj_1000.weights -dont_show -thresh 0.1 ../darknet/funnydog.mp4 -i 0 -out_filename veout_funnydog.avi
# Out:
# Streaming output truncated to the last 5000 lines.
# Objects:
#
#
# FPS:190.6 	 AVG_FPS:191.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:189.6 	 AVG_FPS:191.5
#
#  cvWriteFrame
# Objects:
#
# dog: 12%
#
# FPS:191.2 	 AVG_FPS:191.5
#
#  cvWriteFrame
# Objects:
#
# dog: 13%
#
# FPS:189.7 	 AVG_FPS:191.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:191.2 	 AVG_FPS:191.5
#
#  cvWriteFrame
# Objects:
#
# dog: 27%
#
# FPS:188.9 	 AVG_FPS:191.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:189.9 	 AVG_FPS:191.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:188.2 	 AVG_FPS:191.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:189.0 	 AVG_FPS:191.5
#
#  cvWriteFrame
# Objects:
#
# dog: 23%
#
# FPS:188.3 	 AVG_FPS:191.5
#
#  cvWriteFrame
# Objects:
#
# dog: 10%
#
# FPS:189.5 	 AVG_FPS:191.5
#
#  cvWriteFrame
# Objects:
#
# dog: 11%
#
# FPS:187.9 	 AVG_FPS:191.5
#
#  cvWriteFrame
# Objects:
#
# dog: 11%
#
# FPS:187.2 	 AVG_FPS:191.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:186.4 	 AVG_FPS:191.5
#
#  cvWriteFrame
# Objects:
#
#
# ...
